# %% [markdown]
# # file operations

# %%
# syntax:open(filepath,mode)

# %% [markdown]
# #### r:read()

# %%
file=open(r"C:\Users\ipcs\Desktop\Adarsh.txt","r")
#for i in file:
    #print(i)
file.read()
# Out:
# 'I am learning python'

# %% [markdown]
# #### w:write()

# %%
file1=open(r"C:\Users\ipcs\Desktop\Adarsh.txt","w")
file1.write("My name is Adarsh \n")
file1.write("My name is Bicky \n")
file1.write("We are Data scientist \n")
file1.close()

# %%
file1=open(r"C:\Users\ipcs\Desktop\Bicky.txt","w")
file1.write("We are Learning File Operations \n")

file1.close()

# %% [markdown]
# ### a:append()

# %%
file1=open(r"C:\Users\ipcs\Desktop\Adarsh.txt","a")
file1.write("I am hungry\n")
file1.close()

# %% [markdown]
# ### r+:read and write

# %%
file1=open(r"C:\Users\ipcs\Desktop\Adarsh.txt","r+")
file1.read()
file1.write("We are learning file operations")
#file1.close()
# Out:
# 31

# %% [markdown]
# ## with open()

# %%
l=["i am learning python \n","I am data scientist \n"]

# %%
with open(r"C:\Users\ipcs\Desktop\Adarsh1.txt","w") as new_file:
    new_file.write("Hello\n")
    new_file.writelines(l)

# %% [markdown]
# # Reading excel files

# %%
import pandas as pd

# %%
data=pd.read_excel(r"C:\Users\ipcs\Downloads\Mock_Interview_List.xlsx")

# %%
data
# Out:
#     Unnamed: 0    Day1-Monday,16 Oct 23              Unnamed: 2  \
# 0          1.0          Sarthak Jaiswal         complete python
# 1          2.0             Bicky Sarkar    python- control flow
# 2          3.0              Ankit Patil    python- control flow
# 3          NaN                      NaN                     NaN
# 4          NaN   Day2-Tuesday,17 Oct 23                     NaN
# 5          4.0                   Trupti  python- pandas library
# 6          5.0                 Priyanka  python- pandas library
# 7          6.0                    Sahil  python- pandas library
# 8          NaN                      NaN                     NaN
# 9          NaN  Day3-Wednsday,18 Oct 23                     NaN
# 10         7.0             Adarsh Sinha    python- control flow
# 11         8.0                    Gauri  python- pandas library
# 12         9.0                  Saurabh    python- control flow
# 13        10.0                    Sayli  python- pandas library
# ...

# %%
csv_file=pd.read_csv(r"C:\Users\ipcs\Downloads\Placement (1).csv")
csv_file
# Out:
#          name of company                                  college name  \
# 0                XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1                XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2                XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3                QUINNOX                 PILLAI COLLEGE OF ENGINEERING
# 4                QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# ..                   ...                                           ...
# 457  ARK TECHNOSOLUTIONS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 458             ACCOLITE          K. J. SOMAIYA COLLEGE OF ENGINEERING
# 459             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 460             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 461             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
#
#           region  year   Salary
# 0         MUMBAI  2018   657673
# 1           PUNE  2018   657673
# ...

# %% [markdown]
# # Reading XML file(HTML files)

# %%
import bs4  #package/library

# %%
from bs4 import BeautifulSoup #module  #webscrapping: use to parse the HTML data

# %%
print(dir(BeautifulSoup))
# Out:
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'DEFAULT_INTERESTING_STRING_TYPES', 'EMPTY_ELEMENT_EVENT', 'END_ELEMENT_EVENT', 'NO_PARSER_SPECIFIED_WARNING', 'ROOT_TAG_NAME', 'START_ELEMENT_EVENT', 'STRING_ELEMENT_EVENT', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_clone', '_decode_markup', '_event_stream', '_feed', '_find_all', '_find_one', '_format_tag', '_indent_string', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resemble
# ...

# %%
with open(r"C:\Users\ipcs\Desktop\XML_file.xml") as f:
    data=f.read()

# %%
print(data)
# Out:
# <?xml version="1.0"?>
# <catalog>
#    <book id="bk101">
#       <author>Gambardella, Matthew</author>
#       <title>XML Developer's Guide</title>
#       <genre>Computer</genre>
#       <price>44.95</price>
#       <publish_date>2000-10-01</publish_date>
#       <description>An in-depth look at creating applications
#       with XML.</description>
#    </book>
#
#    </book>
#    <book id="bk109">
#       <author>Kress, Peter</author>
#       <title>Paradox Lost</title>
#       <genre>Science Fiction</genre>
#       <price>6.95</price>
#       <publish_date>2000-11-02</publish_date>
#       <description>After an inadvertant trip through a Heisenberg
#       Uncertainty Device, James Salway discovers the problems
#       of being quantum.</description>

# %%
data1=BeautifulSoup(data)
# Out:
# C:\Users\ipcs\AppData\Local\anaconda3\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
data1
# Out:
# <?xml version="1.0"?><html><body><catalog>
# <book id="bk101">
# <author>Gambardella, Matthew</author>
# <title>XML Developer's Guide</title>
# <genre>Computer</genre>
# <price>44.95</price>
# <publish_date>2000-10-01</publish_date>
# <description>An in-depth look at creating applications
#       with XML.</description>
# </book>
# <book id="bk109">
# <author>Kress, Peter</author>
# <title>Paradox Lost</title>
# <genre>Science Fiction</genre>
# <price>6.95</price>
# <publish_date>2000-11-02</publish_date>
# <description>After an inadvertant trip through a Heisenberg
#       Uncertainty Device, James Salway discovers the problems
#       of being quantum.</description>
# </book></catalog></body></html>

# %%
tags=data1.find_all("title")

# %%
tags
# Out:
# [<title>XML Developer's Guide</title>, <title>Paradox Lost</title>]

# %%
tag=data1.find("title")

# %%
tag.get_text()
# Out:
# "XML Developer's Guide"

# %%
tags=data1.find("title")

# %%
tags
# Out:
# <title>XML Developer's Guide</title>

# %%
#if you apply get_
d1=data1.get_text("title")

# %%
print(d1)
# Out:
# title
# titleGambardella, Matthewtitle
# titleXML Developer's Guidetitle
# titleComputertitle
# title44.95title
# title2000-10-01title
# titleAn in-depth look at creating applications
#       with XML.title
# title
# title
# titleKress, Petertitle
# titleParadox Losttitle
# titleScience Fictiontitle
# title6.95title
# title2000-11-02title
# titleAfter an inadvertant trip through a Heisenberg
#       Uncertainty Device, James Salway discovers the problems
#       of being quantum.title

# %% [markdown]
# # Reading csv files

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\Sample_csv_file.csv")
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
import csv

# %%
with open(r"C:\Users\admin\Downloads\Sample_csv_file.csv",'r') as csvfile:
    csvreader=csv.reader(csvfile)

# %%
print(csvreader)

# %%
class my_class1:
    "i am learning OOPS"
    pass

# %%
print(my_class1.__doc__)
# Out:
# i am learning OOPS

# %%
class person:
    "this is my class"
    age=10
    def greet(self):
        print("hello")

# %%
print(person.age)
# Out:
# 10

# %%
print(person.greet)
# Out:
# <function person.greet at 0x000002CC1B241800>

# %%
{
    
    "emp_details":[
        {
            "emp_name":"Sahil",
            "email": "sahilwagh98@gmail.com",
            "jon_profile": "intern"
        },
        {
            "emp_name": "Sahill",
            "email": "sahilwagh198@gmail.com",
            "jon_profile": "developer"
        }
        
    ]
}
# Out:
# {'emp_details': [{'emp_name': 'Sahil',
#    'email': 'sahilwagh98@gmail.com',
#    'jon_profile': 'intern'},
#   {'emp_name': 'Sahill',
#    'email': 'sahilwagh198@gmail.com',
#    'jon_profile': 'developer'}]}

# %%
import json
s=open(r"C:\Users\ipcs\Desktop\Sahil\Sahil_json.json")

# %%
sahil_json2=json.load(s)

# %%
for i in sahil_json2:
    print(i)
# Out:
# emp_details

# %%
for i in sahil_json2["emp_details"]:
    print(i)
# Out:
# {'emp_name': 'Sahil', 'email': 'sahilwagh98@gmail.com', 'jon_profile': 'intern'}
# {'emp_name': 'Sahill', 'email': 'sahilwagh198@gmail.com', 'jon_profile': 'developer'}

# %%
‪C:\Users\ipcs\Desktop\XML_file.xml

# %%
with open(r"C:\Users\ipcs\Downloads\test_bikes.csv") as test:
    data=test.read()

# %%
data
# Out:
# 'datetime,season,holiday,workingday,weather,temp,atemp,humidity,windspeed\n2011-01-20 00:00:00,1,0,1,1,10.66,11.365,56,26.0027\n2011-01-20 01:00:00,1,0,1,1,10.66,13.635,56,0\n2011-01-20 02:00:00,1,0,1,1,10.66,13.635,56,0\n2011-01-20 03:00:00,1,0,1,1,10.66,12.88,56,11.0014\n2011-01-20 04:00:00,1,0,1,1,10.66,12.88,56,11.0014\n2011-01-20 05:00:00,1,0,1,1,9.84,11.365,60,15.0013\n2011-01-20 06:00:00,1,0,1,1,9.02,10.605,60,15.0013\n2011-01-20 07:00:00,1,0,1,1,9.02,10.605,55,15.0013\n2011-01-20 08:00:00,1,0,1,1,9.02,10.605,55,19.0012\n2011-01-20 09:00:00,1,0,1,2,9.84,11.365,52,15.0013\n2011-01-20 10:00:00,1,0,1,1,10.66,11.365,48,19.9995\n2011-01-20 11:00:00,1,0,1,2,11.48,13.635,45,11.0014\n2011-01-20 12:00:00,1,0,1,2,12.3,16.665,42,0\n2011-01-20 13:00:00,1,0,1,2,11.48,14.395,45,7.0015\n2011-01-20 14:00:00,1,0,1,2,12.3,15.15,45,8.9981\n2011-01-20 15:00:00,1,0,1,2,13.12,15.91,45,12.998\n2011-01-20 16:00:00,1,0,1,2,12.3,15.15,49,8.9981\n2011-01-20 17:00:00,1,0,1,2,12.3,15.91,49,7.0015\n2011-01
# ...

# %%
import bs4

# %%
from bs4 import BeautifulSoap as bs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from bs4 import BeautifulSoap as bs
#
# ImportError: cannot import name 'BeautifulSoap' from 'bs4' (C:\Users\ipcs\AppData\Local\anaconda3\Lib\site-packages\bs4\__init__.py)
